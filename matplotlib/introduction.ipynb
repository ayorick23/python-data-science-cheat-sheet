# %% [markdown]
# # Introduction

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Example data

# %%
#Datos de ejemplo
x = np.linspace(0, 10, 100)
y = np.sin(x)

# %% [markdown]
# ## Create a figure and axis

# %%
#Crear una figura y un eje
fig, ax = plt.subplots()
ax.plot(x, y)

#Titulo y etiquetas
ax.set_title('Grafico de linea basico')
ax.set_xlabel('Eje x')
ax.set_ylabel('Eje y')

#Mostrar el grafico
plt.show()
