# %% [markdown]
# # Bars and Pies

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Data for both graphs

# %%
#Datos para ambos gráficos
categorys = ['A', 'B', 'C', 'D', 'E']
values = [7, 13, 5, 17, 20]

# %% [markdown]
# ## Create the figure and the axes

# %%
#Crear la figura y los ejes
fig, axs = plt.subplots(1, 2, figsize=(12, 6)) #Un gráfico de barras y otro de pastel

##Gráfico de barras
axs[0].bar(categorys, values, color='skyblue', edgecolor="black")

#Personalización
axs[0].set_title("Gráfico de Barras")
axs[0].set_xlabel("Categoría")
axs[0].set_ylabel("Valores")
axs[0].grid(axis="y", linestyle="--", alpha=0.7)

#Gráfico de pastel
axs[1].pie(values, labels=categorys, autopct="%1.1f%%", startangle=90, colors=["blue", "red", "green", "yellow", "purple"], shadow=True)

#Personalización
axs[1].set_title("Gráfico de Pastel")

#Ajustar el layout para evitar sobreposición
plt.tight_layout()

#Mostrar el gráfico
plt.show()

# %% [markdown]
# ### Explanation
# ### Gráfico de Barras:
# - ``axs[0].bar(categorys, values, color="skyblue", edgecolor="black")`` -> Crea las barras con borde negro
# - ``axs[0].grid(axis="y", linestyle="--", alpha=0.7)`` -> Agrega una cuadrícula en el eje Y
#
# ### Gráfico de Pastel:
# - ``axs[1].pie(valores, labels=categorias, autopct="%1.1f%%", startangle=90, shadow=True)``
#     - ``autopct="%1.1f%%"`` -> Muestra los porcentajes en el gráfico
#     - ``startangle=90`` -> Rota el inicio del gráfico en 90°
#     - ``shadow=True`` -> Agrega sombra al gráfico
