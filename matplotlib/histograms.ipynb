# %% [markdown]
# # Histograms

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Generate random data with normal distribution

# %%
#Generar datos aleatorios con distribucion normal
np.random.seed(42) #para reproductibilidad
data = np.random.randn(1000) #1000 valores con distribucion normal

# %% [markdown]
# ## Create the figure and the axis

# %%
#Crear la figura y el eje
fig, ax = plt.subplots(figsize=(8, 6))

#Crear histograma
ax.hist(data, bins=30, color="royalblue", edgecolor="black", alpha=0.7)

#Personalizacion
ax.set_title("Histograma de Distribucion Normal")
ax.set_xlabel("Valores")
ax.set_ylabel("Frecuencia")
ax.grid(axis="y", linestyle="--", alpha=0.7)

#Mostrar la grafica
plt.show()

# %% [markdown]
# ### Explanation
# - ``np.random.randn(1000)`` -> Genera 1000 valores con distribucion normal estandar (media = 0, desviacion estandar = 1)
# - ``bins=30`` -> Numero de barras en el histograma
# - ``color="royalblue"`` -> Color de las barras
# - ``edgecolor="black"`` -> Borde de las barras
# - ``alpha=0.7`` -> Transparencia
# - ``ax.grid(axis="y", linestyle="--", alpha=0.7)`` -> Activa la cuadricula en el eje Y
